# %%
import pandas as pd

# %%
data=pd.read_csv('listings.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8976 entries, 0 to 8975
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            8976 non-null   int64
#  1   listing_url                                   8976 non-null   object
#  2   scrape_id                                     8976 non-null   int64
#  3   last_scraped                                  8976 non-null   object
#  4   source                                        8976 non-null   object
#  5   name                                          8976 non-null   object
#  6   description                                   8714 non-null   object
#  7   neighborhood_overview                         4420 non-null   object
#  8   picture_url                                   8976 non-null   object
# ...

# %%
data.drop(['listing_url','scrape_id','last_scraped','source','name','description','bathrooms_text','neighborhood_overview','picture_url','host_url','host_about','host_thumbnail_url','host_picture_url','neighbourhood_group_cleansed','amenities','minimum_minimum_nights','maximum_minimum_nights','minimum_maximum_nights','calendar_updated','calendar_last_scraped','number_of_reviews_l30d','first_review','license','calculated_host_listings_count_entire_homes','last_review','calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms'],axis=1,inplace=True)

# %%
objs=data.dtypes.reset_index()
objs.head()
# Out:
#            index       0
# 0             id   int64
# 1        host_id   int64
# 2      host_name  object
# 3     host_since  object
# 4  host_location  object

# %%
list(objs[objs[0]=='object']['index'])
# Out:
# ['host_name',
#  'host_since',
#  'host_location',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_neighbourhood',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'property_type',
#  'room_type',
#  'price',
#  'has_availability',
#  'instant_bookable']

# %%
data[['host_name',
 'host_since',
 'host_location',
 'host_response_time',
 'host_response_rate',
 'host_acceptance_rate',
 'host_is_superhost',
 'host_neighbourhood',
 'host_verifications',
 'host_has_profile_pic',
 'host_identity_verified',
 'neighbourhood',
 'neighbourhood_cleansed',
 'property_type',
 'room_type',
 'price',
 'has_availability',
 'instant_bookable']]
# Out:
#                      host_name  host_since     host_location  \
# 0                       Lovely  2020-12-29     Málaga, Spain
# 1                   Airgestión  2014-01-28             Spain
# 2                      Susanna  2014-04-06     Málaga, Spain
# 3     Esther, Francisco & Sara  2013-01-28  Andalusia, Spain
# 4                      Montana  2021-07-19  Andalusia, Spain
# ...                        ...         ...               ...
# 8971                 Alexander  2013-11-12  Andalusia, Spain
# 8972                   Joaquin  2014-10-13  Andalusia, Spain
# 8973                   Leandro  2014-09-19     Málaga, Spain
# 8974                    Stefan  2012-06-14               NaN
# 8975                  Carolina  2014-12-05     Málaga, Spain
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 0         within an hour               100%                 100%
# 1         within an hour               100%                 100%
# ...

# %%
data.shape[1]
# Out:
# 48

# %%
#Corregimos columna
data['price'] = data['price'].str.replace('$', '').str.replace(',', '').astype(float)
data['host_acceptance_rate']=data['host_acceptance_rate'].str.replace('%', '').astype(float)
data['host_response_rate']=data['host_response_rate'].str.replace('%', '').astype(float)
data['host_acceptance_rate']=data['host_acceptance_rate']/100
data['host_response_rate']=data['host_response_rate']/100

# %%
data.shape[1]
# Out:
# 48

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8976 entries, 0 to 8975
# Data columns (total 48 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              8976 non-null   int64
#  1   host_id                         8976 non-null   int64
#  2   host_name                       8976 non-null   object
#  3   host_since                      8976 non-null   object
#  4   host_location                   6926 non-null   object
#  5   host_response_time              8395 non-null   object
#  6   host_response_rate              8395 non-null   float64
#  7   host_acceptance_rate            8594 non-null   float64
#  8   host_is_superhost               8568 non-null   object
#  9   host_neighbourhood              1070 non-null   object
#  10  host_listings_count             8976 non-null   int64
#  11  host_total_listings_count       8976 non-null   int64
# ...

# %%
nulos=data.isnull().sum().reset_index()
nulos=nulos[nulos[0]!=0]
nulos
# Out:
#                           index     0
# 4                 host_location  2050
# 5            host_response_time   581
# 6            host_response_rate   581
# 7          host_acceptance_rate   382
# 8             host_is_superhost   408
# 9            host_neighbourhood  7906
# 15                neighbourhood  4556
# 22                    bathrooms   326
# 23                     bedrooms    66
# 24                         beds   327
# 25                        price   390
# 31             has_availability    60
# 38         review_scores_rating  1213
# 39       review_scores_accuracy  1220
# 40    review_scores_cleanliness  1220
# 41        review_scores_checkin  1220
# 42  review_scores_communication  1220
# 43       review_scores_location  1220
# 44          review_scores_value  1220
# 47            reviews_per_month  1213

# %%
data.columns
# Out:
# Index(['id', 'host_id', 'host_name', 'host_since', 'host_location',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price',
#        'minimum_nights', 'maximum_nights', 'maximum_maximum_nights',
#        'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'number_of_reviews', 'number_of_reviews_ltm',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
# ...

# %%
nulos['index']
# Out:
# 4                   host_location
# 5              host_response_time
# 6              host_response_rate
# 7            host_acceptance_rate
# 8               host_is_superhost
# 9              host_neighbourhood
# 15                  neighbourhood
# 22                      bathrooms
# 23                       bedrooms
# 24                           beds
# 25                          price
# 31               has_availability
# 38           review_scores_rating
# 39         review_scores_accuracy
# 40      review_scores_cleanliness
# 41          review_scores_checkin
# 42    review_scores_communication
# 43         review_scores_location
# 44            review_scores_value
# 47              reviews_per_month
# Name: index, dtype: object

# %%
for i in nulos['index']:
    try:
        float(nulos[i][0])
        data[i]=data[i].fillna(data[i].mean())
    except:
        data[i]=data[i].fillna(method='ffill')
# Out:
# /tmp/ipykernel_6201/30804136.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data[i]=data[i].fillna(method='ffill')

# %%
nulos=data.isnull().sum().reset_index()
nulos=nulos[nulos[0]!=0]
nulos
# Out:
#                  index  0
# 9   host_neighbourhood  1
# 15       neighbourhood  5

# %%
data.dropna(inplace=True)

# %%
nulos=data.isnull().sum().reset_index()
nulos=nulos[nulos[0]!=0]
nulos
# Out:
# Empty DataFrame
# Columns: [index, 0]
# Index: []

# %%
data.isnull().sum()
# Out:
# id                                0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_neighbourhood                0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_has_profile_pic              0
# host_identity_verified            0
# neighbourhood                     0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# price                             0
# ...

# %%
cualitativos=pd.DataFrame()
cuantitativos=pd.DataFrame()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8971 entries, 5 to 8975
# Data columns (total 48 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              8971 non-null   int64
#  1   host_id                         8971 non-null   int64
#  2   host_name                       8971 non-null   object
#  3   host_since                      8971 non-null   object
#  4   host_location                   8971 non-null   object
#  5   host_response_time              8971 non-null   object
#  6   host_response_rate              8971 non-null   float64
#  7   host_acceptance_rate            8971 non-null   float64
#  8   host_is_superhost               8971 non-null   object
#  9   host_neighbourhood              8971 non-null   object
#  10  host_listings_count             8971 non-null   int64
#  11  host_total_listings_count       8971 non-null   int64
# ...

# %%
iterador1=data.dtypes.reset_index()
iterador=iterador1[0]
iterador1=iterador1[['index']]

# %%
iterador1
# Out:
#                              index
# 0                               id
# 1                          host_id
# 2                        host_name
# 3                       host_since
# 4                    host_location
# 5               host_response_time
# 6               host_response_rate
# 7             host_acceptance_rate
# 8                host_is_superhost
# 9               host_neighbourhood
# 10             host_listings_count
# 11       host_total_listings_count
# 12              host_verifications
# 13            host_has_profile_pic
# 14          host_identity_verified
# 15                   neighbourhood
# 16          neighbourhood_cleansed
# 17                        latitude
# 18                       longitude
# 19                   property_type
# 20                       room_type
# 21                    accommodates
# 22                       bathrooms
# 23                        bedrooms
# 24                            beds
# 25                           price
# ...

# %%
iterador
# Out:
# 0       int64
# 1       int64
# 2      object
# 3      object
# 4      object
# 5      object
# 6     float64
# 7     float64
# 8      object
# 9      object
# 10      int64
# 11      int64
# 12     object
# 13     object
# 14     object
# 15     object
# 16     object
# 17    float64
# 18    float64
# 19     object
# 20     object
# 21      int64
# 22    float64
# 23    float64
# 24    float64
# 25    float64
# 26      int64
# 27      int64
# 28      int64
# 29    float64
# 30    float64
# 31     object
# 32      int64
# 33      int64
# 34      int64
# 35      int64
# 36      int64
# 37      int64
# 38    float64
# 39    float64
# 40    float64
# 41    float64
# 42    float64
# 43    float64
# 44    float64
# 45     object
# 46      int64
# 47    float64
# Name: 0, dtype: object

# %%
contador=0
for i in iterador:
    print(i)
    if i=='object':
        cualitativos=pd.concat([cualitativos,data[data.columns[contador]]],axis=1)
    else:
        cuantitativos=pd.concat([cuantitativos,data[data.columns[contador]]],axis=1)
    contador+=1
# Out:
# int64
# int64
# object
# object
# object
# object
# float64
# float64
# object
# object
# int64
# int64
# object
# object
# object
# object
# object
# float64
# float64
# object
# object
# int64
# float64
# float64
# float64
# float64
# int64
# int64
# int64
# float64
# float64
# object
# int64
# int64
# int64
# int64
# int64
# int64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# object
# int64
# float64

# %%
cualitativos.shape[1]
# Out:
# 15

# %%
cuantitativos.shape[1]
# Out:
# 33

# %%
#cualitativos.to_csv('cualitativos.csv')

# %%
#cuantitativos.to_csv('cuantitativos.csv')

# %%
import matplotlib.pyplot as plt

# %%
#Realizamos diagrama de caja o bigote de cada columna del DF
fig= plt.figure(figsize=(15 ,8))
cuantitativos['reviews_per_month'].plot(kind='box', vert=False)
plt.title('Valores Atípicos del Malaga')
plt.show() #Dibujamos el diagrama

# %%
y=cuantitativos
Limite_Superior= y.mean()+ 3*y.std()
Limite_Inferior= y.mean()- 3*y.std()
print('-Límite superior permitido\n', Limite_Superior,'\n')
print('-Límite inferior permitido\n', Limite_Inferior)
# Out:
# -Límite superior permitido
#  id                                1.946468e+18
# host_id                           7.372639e+08
# host_response_rate                1.343534e+00
# host_acceptance_rate              1.448160e+00
# host_listings_count               3.253884e+02
# host_total_listings_count         5.386678e+02
# latitude                          3.676180e+01
# longitude                        -4.346441e+00
# accommodates                      1.066925e+01
# bathrooms                         3.346624e+00
# bedrooms                          5.345092e+00
# beds                              8.546774e+00
# price                             1.013452e+03
# minimum_nights                    4.148511e+01
# maximum_nights                    1.810314e+03
# maximum_maximum_nights            2.043332e+03
# minimum_nights_avg_ntm            3.962143e+01
# maximum_nights_avg_ntm            1.997357e+03
# availability_30                   3.720360e+01
# ...

# %%
data2= cuantitativos[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data2
# Out:
#                        id    host_id  host_response_rate  \
# 5                52295523  422798059                1.00
# 6     1105849600091052946  446668777                1.00
# 7                31748629  126386697                1.00
# 8     1151936773590880075  399961266                1.00
# 9      701861352072019656  428065882                1.00
# ...                   ...        ...                 ...
# 8971   835976859934550613    9960184                1.00
# 8972             49747007   22481967                1.00
# 8973   774557366205990523   21521353                1.00
# 8974   901899213240359171    2634139                1.00
# 8975  1044163931591337291   24525026                0.99
#
#       host_acceptance_rate  host_listings_count  host_total_listings_count  \
# 5                     1.00                  3.0                        3.0
# 6                     1.00                  1.0                        1.0
# ...

# %%
valores_nulos= data2.isnull().sum()
valores_nulos
# Out:
# id                                  0
# host_id                             0
# host_response_rate                186
# host_acceptance_rate              277
# host_listings_count               162
# host_total_listings_count         110
# latitude                          208
# longitude                         149
# accommodates                      172
# bathrooms                         134
# bedrooms                           93
# beds                              131
# price                              49
# minimum_nights                     76
# maximum_nights                      0
# maximum_maximum_nights              0
# minimum_nights_avg_ntm             83
# maximum_nights_avg_ntm              0
# availability_30                     0
# availability_60                     0
# availability_90                     0
# availability_365                    0
# number_of_reviews                 224
# number_of_reviews_ltm             163
# review_scores_rating              168
# ...

# %%
data_clean=data2.copy()
data_clean=data_clean.fillna(round(data2.mean(),1))
data_clean
# Out:
#                        id    host_id  host_response_rate  \
# 5                52295523  422798059                1.00
# 6     1105849600091052946  446668777                1.00
# 7                31748629  126386697                1.00
# 8     1151936773590880075  399961266                1.00
# 9      701861352072019656  428065882                1.00
# ...                   ...        ...                 ...
# 8971   835976859934550613    9960184                1.00
# 8972             49747007   22481967                1.00
# 8973   774557366205990523   21521353                1.00
# 8974   901899213240359171    2634139                1.00
# 8975  1044163931591337291   24525026                0.99
#
#       host_acceptance_rate  host_listings_count  host_total_listings_count  \
# 5                     1.00                  3.0                        3.0
# 6                     1.00                  1.0                        1.0
# ...

# %%
valores_nulos= data_clean.isnull().sum()
valores_nulos
# Out:
# id                                0
# host_id                           0
# host_response_rate                0
# host_acceptance_rate              0
# host_listings_count               0
# host_total_listings_count         0
# latitude                          0
# longitude                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# price                             0
# minimum_nights                    0
# maximum_nights                    0
# maximum_maximum_nights            0
# minimum_nights_avg_ntm            0
# maximum_nights_avg_ntm            0
# availability_30                   0
# availability_60                   0
# availability_90                   0
# availability_365                  0
# number_of_reviews                 0
# number_of_reviews_ltm             0
# review_scores_rating              0
# review_scores_accuracy            0
# ...

# %%
y=cuantitativos

percentiles25=y.quantile(0.25) #Q1
percentiles75=y.quantile(0.75) #Q3
iqr= percentiles75-percentiles25

Limite_Superior_iqr=percentiles75 + 1.5*iqr
Limite_Inferior_iqr=percentiles25- 1.5*iqr
print("Límite superior permitido: \n",Limite_Superior_iqr)
print("\nLímite inferior permitido: \n",Limite_Inferior_iqr)
# Out:
# Límite superior permitido:
#  id                                2.412564e+18
# host_id                           7.615315e+08
# host_response_rate                1.000000e+00
# host_acceptance_rate              1.030000e+00
# host_listings_count               1.095000e+02
# host_total_listings_count         1.320000e+02
# latitude                          3.673605e+01
# longitude                        -4.399468e+00
# accommodates                      9.500000e+00
# bathrooms                         2.250000e+00
# bedrooms                          3.500000e+00
# beds                              6.000000e+00
# price                             2.800000e+02
# minimum_nights                    6.000000e+00
# maximum_nights                    2.572500e+03
# maximum_maximum_nights            2.265000e+03
# minimum_nights_avg_ntm            6.250000e+00
# maximum_nights_avg_ntm            2.265000e+03
# availability_30                   3.550000e+01
# ...

# %%
data2_iqr=cuantitativos[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data2_iqr
# Out:
#                        id    host_id  host_response_rate  \
# 5                52295523  422798059                 1.0
# 6     1105849600091052946  446668777                 1.0
# 7                31748629  126386697                 1.0
# 8     1151936773590880075  399961266                 1.0
# 9      701861352072019656  428065882                 1.0
# ...                   ...        ...                 ...
# 8971   835976859934550613    9960184                 1.0
# 8972             49747007   22481967                 1.0
# 8973   774557366205990523   21521353                 1.0
# 8974   901899213240359171    2634139                 1.0
# 8975  1044163931591337291   24525026                 NaN
#
#       host_acceptance_rate  host_listings_count  host_total_listings_count  \
# 5                     1.00                  3.0                        3.0
# 6                     1.00                  1.0                        1.0
# ...

# %%
valores_nulos=data2_iqr.isnull().sum()
valores_nulos
# Out:
# id                                   0
# host_id                              0
# host_response_rate                2131
# host_acceptance_rate              1682
# host_listings_count                818
# host_total_listings_count          924
# latitude                          1136
# longitude                         1543
# accommodates                       238
# bathrooms                          435
# bedrooms                           514
# beds                               274
# price                              640
# minimum_nights                     335
# maximum_nights                       0
# maximum_maximum_nights               0
# minimum_nights_avg_ntm             474
# maximum_nights_avg_ntm               0
# availability_30                      0
# availability_60                      0
# availability_90                      0
# availability_365                     0
# number_of_reviews                  931
# number_of_reviews_ltm              658
# ...

# %%
data_3_iqr= data2_iqr.copy()
data_3_iqr=data_3_iqr.fillna(round(data2_iqr.mean(),1))

# %%
fig= plt.figure(figsize=(15 ,8))
data_clean['reviews_per_month'].plot(kind='box', vert=False)
plt.title('Valores Atípicos Procedimiento "Desviación Estandar" para eliminar outliers en el DF')
plt.show() #Dibujamos el diagrama

# %%
fig = plt.figure(figsize =(15, 8))
data_3_iqr['reviews_per_month'].plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
# Out:
# Text(0.5, 1.0, 'Valores Atípicos del Dataframe')

# %%
datos_limpios_iqr=pd.concat([cualitativos,data_3_iqr], axis=1)
datos_limpios_iqr.head()
# Out:
#         host_name  host_since  host_location host_response_time  \
# 5  Carlos Alberto  2021-09-13  Málaga, Spain     within an hour
# 6            Rodo  2022-02-24  Málaga, Spain     within an hour
# 7          Lu&Cia  2017-04-18  Málaga, Spain     within an hour
# 8        Gestitur  2021-05-04  Málaga, Spain     within an hour
# 9           Maria  2021-10-19  Málaga, Spain     within an hour
#
#   host_is_superhost                               host_neighbourhood  \
# 5                 t  Conjunto Residencial Playa las Gaviotas Fase VI
# 6                 f  Conjunto Residencial Playa las Gaviotas Fase VI
# 7                 f  Conjunto Residencial Playa las Gaviotas Fase VI
# 8                 f  Conjunto Residencial Playa las Gaviotas Fase VI
# 9                 f  Conjunto Residencial Playa las Gaviotas Fase VI
#
#                  host_verifications host_has_profile_pic  \
# 5                ['email', 'phone']                    t
# ...

# %%
datos_limpios_desvest=pd.concat([cualitativos,data_clean],axis=1)
datos_limpios_desvest.head()
# Out:
#         host_name  host_since  host_location host_response_time  \
# 5  Carlos Alberto  2021-09-13  Málaga, Spain     within an hour
# 6            Rodo  2022-02-24  Málaga, Spain     within an hour
# 7          Lu&Cia  2017-04-18  Málaga, Spain     within an hour
# 8        Gestitur  2021-05-04  Málaga, Spain     within an hour
# 9           Maria  2021-10-19  Málaga, Spain     within an hour
#
#   host_is_superhost                               host_neighbourhood  \
# 5                 t  Conjunto Residencial Playa las Gaviotas Fase VI
# 6                 f  Conjunto Residencial Playa las Gaviotas Fase VI
# 7                 f  Conjunto Residencial Playa las Gaviotas Fase VI
# 8                 f  Conjunto Residencial Playa las Gaviotas Fase VI
# 9                 f  Conjunto Residencial Playa las Gaviotas Fase VI
#
#                  host_verifications host_has_profile_pic  \
# 5                ['email', 'phone']                    t
# ...

# %%
city=datos_limpios_iqr.copy()

# %%
city.head()
# Out:
#         host_name  host_since  host_location host_response_time  \
# 5  Carlos Alberto  2021-09-13  Málaga, Spain     within an hour
# 6            Rodo  2022-02-24  Málaga, Spain     within an hour
# 7          Lu&Cia  2017-04-18  Málaga, Spain     within an hour
# 8        Gestitur  2021-05-04  Málaga, Spain     within an hour
# 9           Maria  2021-10-19  Málaga, Spain     within an hour
#
#   host_is_superhost                               host_neighbourhood  \
# 5                 t  Conjunto Residencial Playa las Gaviotas Fase VI
# 6                 f  Conjunto Residencial Playa las Gaviotas Fase VI
# 7                 f  Conjunto Residencial Playa las Gaviotas Fase VI
# 8                 f  Conjunto Residencial Playa las Gaviotas Fase VI
# 9                 f  Conjunto Residencial Playa las Gaviotas Fase VI
#
#                  host_verifications host_has_profile_pic  \
# 5                ['email', 'phone']                    t
# ...

# %%
tipos=city.dtypes.reset_index()
city[tipos[tipos[0]!='object']['index']].columns
# Out:
# Index(['id', 'host_id', 'host_response_rate', 'host_acceptance_rate',
#        'host_listings_count', 'host_total_listings_count', 'latitude',
#        'longitude', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price',
#        'minimum_nights', 'maximum_nights', 'maximum_maximum_nights',
#        'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'number_of_reviews', 'number_of_reviews_ltm', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
'availability_60', 'availability_90', 'availability_365', 'number_of_reviews_ltm', 'reviews_per_month'
# Out:
# ('availability_60',
#  'availability_90',
#  'availability_365',
#  'number_of_reviews_ltm',
#  'reviews_per_month')

# %%
def strugens(city,columna):
    import numpy as np
    #n=city.shape[0]
    Max=city[columna].max()
    Min=city[columna].min()
    R=Max-Min
    ni= 1+3.32*np.log10(Max)
    #i=R/ni
    return np.linspace(Min,Max,round(ni))

# %%
'availability_60'
# Out:
# 'availability_60'

# %%
strugens(city,'availability_60')
# Out:
# array([ 0., 10., 20., 30., 40., 50., 60.])

# %%
n=city.shape[0]
n
# Out:
# 8971

# %%
#Obtenemos el limite superior y el limite inferior de la colmna objetivo
Max=city['availability_60'].max()
Min=city['availability_60'].min()
Limites= [Min, Max]
Limites
# Out:
# [0, 60]

# %%
R=Max-Min
R
# Out:
# 60

# %%
import numpy as np

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# 14.123431644163329

# %%
#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# 4.248259312020368

# %%
#Categorización de variables
intervalos=np.linspace(Min,Max,round(ni))
intervalos
# Out:
# array([ 0.        ,  4.61538462,  9.23076923, 13.84615385, 18.46153846,
#        23.07692308, 27.69230769, 32.30769231, 36.92307692, 41.53846154,
#        46.15384615, 50.76923077, 55.38461538, 60.        ])

# %%
round(ni)
# Out:
# 14

# %%
categorias=['Disponible','Poco disponible','Muy disponible','Accesible','Limitado','Abundante','Escaso','Frecuente','Raro','Común','Infrecuente','Suficiente','Insuficiente','Excesivo']

# %%
strugens(city,'availability_90')
# Out:
# array([ 0., 15., 30., 45., 60., 75., 90.])

# %%
categorias=['Escaso','Limitado','Poco disponible','Accesible','Disponible','Muy disponible','Excesivo']

# %%
city['availability_60']=pd.cut(x=city['availability_60'],bins=int(len(strugens(city,'availability_60'))),labels=categorias)

# %%
city['availability_90']=pd.cut(x=city['availability_90'],bins=int(len(strugens(city,'availability_90'))),labels=categorias)

# %%
categorias=['Indisponible','Escaso','Limitado','Poco disponible','Raro','Común','Accesible','Disponible','Muy disponible','Excesivo']

# %%
city['availability_365']=pd.cut(x=city['availability_365'],bins=int(len(strugens(city,'availability_365'))),labels=categorias)

# %%
len(strugens(city,'number_of_reviews_ltm'))
# Out:
# 6

# %%
categorias=['Nulas','Muy pocas','Pocas','Algunas','Muchas','Muchísimas']

# %%
city['number_of_reviews_ltm']=pd.cut(x=city['number_of_reviews_ltm'],bins=int(len(strugens(city,'number_of_reviews_ltm'))),labels=categorias)

# %%
categorias=['Pocas','Algunas','Muchas']

# %%
city['reviews_per_month']=pd.cut(x=city['reviews_per_month'],bins=int(len(strugens(city,'reviews_per_month'))),labels=categorias)

# %%
city['reviews_per_month'].isnull().sum()
# Out:
# 0

# %%
len(strugens(city,'host_response_rate'))
# Out:
# 1

# %%
categorias=['Algunas']

# %%
city['host_response_rate']=pd.cut(x=city['host_response_rate'],bins=int(len(strugens(city,'host_response_rate'))),labels=categorias)

# %%
city['host_acceptance_rate']=pd.cut(x=city['host_acceptance_rate'],bins=int(len(strugens(city,'host_acceptance_rate'))),labels=categorias)

# %%
len(strugens(city,'host_total_listings_count'))
# Out:
# 8

# %%
categorias=['Nulas','Muy pocas','Insatisfactorio','Pocas','Algunas','Suficientes','Muchas','Muchísimas']

# %%
city['host_total_listings_count']=pd.cut(x=city['host_total_listings_count'],bins=int(len(strugens(city,'host_total_listings_count'))),labels=categorias)

# %%
categorias=['Muy pocas','Algunas','Suficientes','Muchas']

# %%
city['accommodates']=pd.cut(x=city['accommodates'],bins=int(len(strugens(city,'accommodates'))),labels=categorias)

# %%
city['beds']=pd.cut(x=city['beds'],bins=int(len(strugens(city,'beds'))),labels=categorias)

# %%
city['price'].min()
# Out:
# 8.0

# %%
city['price'].max()
# Out:
# 280.0

# %%
categorias=['8-20 EUR','21-50 EUR','51-70 EUR','71-100 EUR','101-130 EUR','131-150 EUR','151-190 EUR','191-220 EUR','221-280 EUR']

# %%
city['price']=pd.cut(x=city['price'],bins=int(len(strugens(city,'price'))),labels=categorias)

# %%
len(strugens(city,'maximum_nights_avg_ntm'))
# Out:
# 11

# %%
categorias=['Nulas','OMG','Incipientes','Muy pocas','Insatisfactorio','Pocas','Algunas','Suficientes','Muchas','Muchísimas','Increíble']

# %%
city['maximum_nights_avg_ntm']=pd.cut(x=city['maximum_nights_avg_ntm'],bins=int(len(strugens(city,'maximum_nights_avg_ntm'))),labels=categorias)

# %%
len(strugens(city,'number_of_reviews'))
# Out:
# 8

# %%
categorias=['Nulas','Muy pocas','Insatisfactorio','Pocas','Algunas','Suficientes','Muchas','Muchísimas']

# %%
city['number_of_reviews']=pd.cut(x=city['number_of_reviews'],bins=int(len(strugens(city,'number_of_reviews'))),labels=categorias)

# %%
len(strugens(city,'review_scores_value'))
# Out:
# 3

# %%
categorias=['Pocas','Algunas','Muchas']

# %%
city['review_scores_value']=pd.cut(x=city['review_scores_value'],bins=int(len(strugens(city,'review_scores_value'))),labels=categorias)

# %%
#datos_limpios_desvest.to_csv('datos_limpios_desvest.csv')
#datos_limpios_iqr.to_csv('datos_limpios_iqr.csv')

# %%
city.columns
# Out:
# Index(['host_name', 'host_since', 'host_location', 'host_response_time',
#        'host_is_superhost', 'host_neighbourhood', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'property_type', 'room_type',
#        'has_availability', 'instant_bookable', 'id', 'host_id',
#        'host_response_rate', 'host_acceptance_rate', 'host_listings_count',
#        'host_total_listings_count', 'latitude', 'longitude', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'price', 'minimum_nights',
#        'maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'number_of_reviews',
#        'number_of_reviews_ltm', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
# ...

# %%
tipos=city.dtypes.reset_index()
categoricas=list(city[tipos[tipos[0]!='object']['index']].columns)
categoricas=city[categoricas]

# %%
from funpymodeling.exploratory import freq_tbl

# %%
freq_tbl(categoricas)
# Out:
#   host_response_rate  frequency  percentage  cumulative_perc
# 0            Algunas       8971         1.0              1.0
#
# ----------------------------------------------------------------
#
#   host_acceptance_rate  frequency  percentage  cumulative_perc
# 0              Algunas       8971         1.0              1.0
#
# ----------------------------------------------------------------
#
#   host_total_listings_count  frequency  percentage  cumulative_perc
# 0                     Nulas       5441    0.606510         0.606510
# 1                 Muy pocas       1698    0.189277         0.795786
# 2           Insatisfactorio        433    0.048267         0.844053
# 3               Suficientes        418    0.046595         0.890648
# 4                     Pocas        387    0.043139         0.933787
# 5                   Algunas        249    0.027756         0.961543
# 6                    Muchas        223    0.024858         0.986401
# ...

# %%
df=freq_tbl(categoricas['price'])
df
# Out:
#          price  frequency  percentage  cumulative_perc
# 0   71-100 EUR       2776    0.309442         0.309442
# 1    51-70 EUR       1821    0.202987         0.512429
# 2  101-130 EUR       1430    0.159403         0.671831
# 3  131-150 EUR        815    0.090848         0.762680
# 4    21-50 EUR        742    0.082711         0.845391
# 5  151-190 EUR        500    0.055735         0.901126
# 6     8-20 EUR        372    0.041467         0.942593
# 7  191-220 EUR        293    0.032661         0.975254
# 8  221-280 EUR        222    0.024746         1.000000

# %%
df.drop(columns=['percentage','cumulative_perc'])
# Out:
#          price  frequency
# 0   71-100 EUR       2776
# 1    51-70 EUR       1821
# 2  101-130 EUR       1430
# 3  131-150 EUR        815
# 4    21-50 EUR        742
# 5  151-190 EUR        500
# 6     8-20 EUR        372
# 7  191-220 EUR        293
# 8  221-280 EUR        222

# %%
df2=df.drop(columns=['percentage','cumulative_perc'])

# %%
Filtro=df2[df2['frequency']>1]
Filtro
# Out:
#          price  frequency
# 0   71-100 EUR       2776
# 1    51-70 EUR       1821
# 2  101-130 EUR       1430
# 3  131-150 EUR        815
# 4    21-50 EUR        742
# 5  151-190 EUR        500
# 6     8-20 EUR        372
# 7  191-220 EUR        293
# 8  221-280 EUR        222

# %%
Filtro_index=Filtro.set_index('price')
Filtro_index
# Out:
#              frequency
# price
# 71-100 EUR        2776
# 51-70 EUR         1821
# 101-130 EUR       1430
# 131-150 EUR        815
# 21-50 EUR          742
# 151-190 EUR        500
# 8-20 EUR           372
# 191-220 EUR        293
# 221-280 EUR        222

# %%
Filtro_index.plot(kind='bar',width=0.8,figsize=(10,4))
plt.title('Precio vs frecuencias')
plt.xlabel('Rango de precios')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
df.plot('frequency','cumulative_perc',kind='scatter')
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
Filtro_index.plot(kind='area',figsize=(10,4),alpha=0.5)
# Out:
# <Axes: xlabel='price'>

# %%
Filtro_index['frequency'].plot(kind='pie',figsize=(10,5),shadow=True,autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
df.plot.hexbin('frequency','cumulative_perc',figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
contador=1
for i in categoricas.columns:
    try:
        float(categoricas[i][10])
        continue
    except:
        print(i)
        print(contador)
        tabla=freq_tbl(categoricas[i])
        tabla.drop(columns=['percentage','cumulative_perc'],inplace=True)
        Filtro=tabla[tabla['frequency']>1]
        Filtro_index=Filtro.set_index(i)
        plt.figure()
        Filtro_index['frequency'].plot(kind='pie',figsize=(10,5),shadow=True,autopct="%0.1f %%")
        plt.title(i)
        #plt.ylabel('Frecuencia')
    contador+=1
# Out:
# host_response_rate
# 1
# host_acceptance_rate
# 2
# host_total_listings_count
# 3
# accommodates
# 4
# beds
# 5
# price
# 6
# maximum_nights_avg_ntm
# 7
# availability_60
# 8
# availability_90
# 9
# availability_365
# 10
# number_of_reviews
# 11
# number_of_reviews_ltm
# 12
# review_scores_value
# 13
# reviews_per_month
# 14
