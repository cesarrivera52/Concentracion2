# %%
import pandas as pd

# %%
data_CDMX=pd.read_csv('CDMX.csv')
data_CDMX.drop(columns='Unnamed: 0',inplace=True)
data_CDMX['price']=data_CDMX['price']*0.051

# %%
data_CDMX['clave_ciudad']=['CDMX' for i in range(data_CDMX.shape[0])]

# %%
data_CDMX.columns
# Out:
# Index(['host_name', 'host_since', 'host_location', 'host_response_time',
#        'host_is_superhost', 'host_neighbourhood', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'property_type', 'room_type',
#        'has_availability', 'instant_bookable', 'id', 'host_id',
#        'host_response_rate', 'host_acceptance_rate', 'host_listings_count',
#        'host_total_listings_count', 'latitude', 'longitude', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'price', 'minimum_nights',
#        'maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'number_of_reviews',
#        'number_of_reviews_ltm', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
# ...

# %%
data_CDMX.reindex(columns=['clave_ciudad','host_name', 'host_since', 'host_location', 'host_response_time',
       'host_is_superhost', 'host_neighbourhood', 'host_verifications',
       'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
       'neighbourhood_cleansed', 'property_type', 'room_type',
       'has_availability', 'instant_bookable', 'id', 'host_id',
       'host_response_rate', 'host_acceptance_rate', 'host_listings_count',
       'host_total_listings_count', 'latitude', 'longitude', 'accommodates',
       'bathrooms', 'bedrooms', 'beds', 'price', 'minimum_nights',
       'maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm',
       'maximum_nights_avg_ntm', 'availability_30', 'availability_60',
       'availability_90', 'availability_365', 'number_of_reviews',
       'number_of_reviews_ltm', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value',
       'calculated_host_listings_count', 'reviews_per_month'])
# Out:
#       clave_ciudad host_name  host_since        host_location  \
# 0             CDMX     Marco  2013-01-21  Mexico City, Mexico
# 1             CDMX      Dici  2010-06-28  Mexico City, Mexico
# 2             CDMX  Fernando  2010-08-09  Mexico City, Mexico
# 3             CDMX   Martina  2013-01-09  Mexico City, Mexico
# 4             CDMX  Nicholas  2011-01-04  Mexico City, Mexico
# ...            ...       ...         ...                  ...
# 26531         CDMX      Elvy  2014-07-31  Mexico City, Mexico
# 26532         CDMX   Nicolas  2013-07-23  Mexico City, Mexico
# 26533         CDMX    Sandra  2015-12-09      Cocoyoc, Mexico
# 26534         CDMX   Salomon  2017-08-22  Mexico City, Mexico
# 26535         CDMX   HostPal  2016-04-16  Mexico City, Mexico
#
#        host_response_time host_is_superhost  \
# 0          within an hour                 t
# 1      a few days or more                 f
# 2          within an hour                 t
# ...

# %%
data_RIO=pd.read_csv('RIO_DE_JANEIRO.csv')#YA TIENE DOLAR
data_RIO.drop(columns='Unnamed: 0',inplace=True)
data_RIO['clave_ciudad']=['RIO' for i in range(data_RIO.shape[0])]
data_RIO.reindex(columns=['clave_ciudad','host_name', 'host_since', 'host_location', 'host_response_time',
       'host_is_superhost', 'host_neighbourhood', 'host_verifications',
       'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
       'neighbourhood_cleansed', 'property_type', 'room_type',
       'has_availability', 'instant_bookable', 'id', 'host_id',
       'host_response_rate', 'host_acceptance_rate', 'host_listings_count',
       'host_total_listings_count', 'latitude', 'longitude', 'accommodates',
       'bathrooms', 'bedrooms', 'beds', 'price', 'minimum_nights',
       'maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm',
       'maximum_nights_avg_ntm', 'availability_30', 'availability_60',
       'availability_90', 'availability_365', 'number_of_reviews',
       'number_of_reviews_ltm', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value',
       'calculated_host_listings_count', 'reviews_per_month'])
# Out:
#       clave_ciudad                 host_name host_since  \
# 0              RIO                  Matthias   08/01/10
# 1              RIO                   Viviane   03/04/10
# 2              RIO                   Taciana   11/09/11
# 3              RIO  Patricia Miranda & Paulo   27/06/10
# 4              RIO                ❤️ BrUx ❤️   12/04/11
# ...            ...                       ...        ...
# 34659          RIO                Jorge Luiz   06/12/20
# 34660          RIO                     Kelen   14/08/17
# 34661          RIO                Jorge Luiz   06/12/20
# 34662          RIO                  Domingos   17/03/22
# 34663          RIO                   Leticia   05/04/21
#
#                          host_location  host_response_time host_is_superhost  \
# 0               Rio de Janeiro, Brazil      within an hour                 t
# 1               Rio de Janeiro, Brazil      within an hour                 t
# ...

# %%
data_MALAGA=pd.read_csv('MALAGA.csv')
data_MALAGA.drop(columns='Unnamed: 0',inplace=True)
data_MALAGA['price']=data_MALAGA['price'].str.replace('$','').str.replace(',','').astype(float)*1.10
data_MALAGA['clave_ciudad']=['MALAGA' for i in range(data_MALAGA.shape[0])]
data_MALAGA.reindex(columns=['clave_ciudad','host_name', 'host_since', 'host_location', 'host_response_time',
       'host_is_superhost', 'host_neighbourhood', 'host_verifications',
       'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
       'neighbourhood_cleansed', 'property_type', 'room_type',
       'has_availability', 'instant_bookable', 'id', 'host_id',
       'host_response_rate', 'host_acceptance_rate', 'host_listings_count',
       'host_total_listings_count', 'latitude', 'longitude', 'accommodates',
       'bathrooms', 'bedrooms', 'beds', 'price', 'minimum_nights',
       'maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm',
       'maximum_nights_avg_ntm', 'availability_30', 'availability_60',
       'availability_90', 'availability_365', 'number_of_reviews',
       'number_of_reviews_ltm', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value',
       'calculated_host_listings_count', 'reviews_per_month'])
# Out:
#      clave_ciudad       host_name  host_since     host_location  \
# 0          MALAGA  Carlos Alberto  2021-09-13     Málaga, Spain
# 1          MALAGA            Rodo  2022-02-24     Málaga, Spain
# 2          MALAGA          Lu&Cia  2017-04-18     Málaga, Spain
# 3          MALAGA        Gestitur  2021-05-04     Málaga, Spain
# 4          MALAGA           Maria  2021-10-19     Málaga, Spain
# ...           ...             ...         ...               ...
# 8966       MALAGA       Alexander  2013-11-12  Andalusia, Spain
# 8967       MALAGA         Joaquin  2014-10-13  Andalusia, Spain
# 8968       MALAGA         Leandro  2014-09-19     Málaga, Spain
# 8969       MALAGA          Stefan  2012-06-14     Málaga, Spain
# 8970       MALAGA        Carolina  2014-12-05     Málaga, Spain
#
#       host_response_time host_is_superhost  \
# 0         within an hour                 t
# 1         within an hour                 f
# 2         within an hour                 f
# ...

# %%
dependientes=pd.concat([data_RIO,data_CDMX,data_MALAGA])[['clave_ciudad','host_acceptance_rate','review_scores_location',
                                                          'host_acceptance_rate','availability_365',
                                                          'host_acceptance_rate','reviews_per_month']]
dependientes.to_csv('dependientes.csv')

# %%
independientes=pd.concat([data_RIO,data_CDMX,data_MALAGA])[['clave_ciudad','host_response_rate','review_scores_cleanliness',
                                                          'price','number_of_reviews',
                                                          'number_of_reviews','review_scores_communication']]
independientes.to_csv('independientes.csv')
